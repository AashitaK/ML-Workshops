# %% [markdown]
# # To Do:
#
# 1. Add estimated time for each of the following:
#     - Some more feature engineering on the Titanic dataset: 25 min
#     - Creating a new column using grouping on two columns: 10
#     - Merging columns from different datasets: 10 min
#
# 2. The alloted time for this exercise is approx 45 min. Should I add optional exercises? (Yes/No)
#
# 3. Add corrections, comments, suggestions and feedback at the bottom of the notebook.
#
# 4. Email me your notebook with the solutions.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Some more feature engineering on the Titanic dataset:
# Loading the dataset:

# %%
train = pd.read_csv('train.csv') 
test = pd.read_csv('test.csv')

# %% [markdown]
# Create a DataFrame named `df` by concatenating the `train` and `test` dataset. Hint: Use `concat()`.

# %%
df = pd.concat([train, test], sort=False)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Create a new column named *Family* by adding the columns *SibSp* and *Parch* and then add 1 to it. Hint: Simply do `C = A + B + 1`.

# %%
df['Family'] = df['SibSp'].add(df['Parch'], fill_value=0) + 1

# %% [markdown]
# Now we check the survival rates with respect to the family size.

# %%
sns.barplot(x='Family', y='Survived', data=df);

# %% [markdown]
# Some passengers that appear to be traveling alone by account of their family size were part of a group traveling on the same ticket.

# %%
df[df['Ticket'] == "1601"]
# Out:
#      PassengerId  Survived  Pclass             Name   Sex   Age  SibSp  Parch  \
# 74            75       1.0       3    Bing, Mr. Lee  male  32.0      0      0
# 169          170       0.0       3    Ling, Mr. Lee  male  28.0      0      0
# 509          510       1.0       3   Lang, Mr. Fang  male  26.0      0      0
# 643          644       1.0       3  Foo, Mr. Choong  male   NaN      0      0
# 692          693       1.0       3     Lam, Mr. Ali  male   NaN      0      0
# 826          827       0.0       3     Lam, Mr. Len  male   NaN      0      0
# 838          839       1.0       3  Chip, Mr. Chang  male  32.0      0      0
# 39           931       NaN       3    Hee, Mr. Ling  male   NaN      0      0
#
#     Ticket     Fare Cabin Embarked  Family
# 74    1601  56.4958   NaN        S       1
# 169   1601  56.4958   NaN        S       1
# 509   1601  56.4958   NaN        S       1
# 643   1601  56.4958   NaN        S       1
# 692   1601  56.4958   NaN        S       1
# 826   1601  56.4958   NaN        S       1
# 838   1601  56.4958   NaN        S       1
# 39    1601  56.4958   NaN        S       1

# %% [markdown]
# One can check that there are many tickets shared among passengers that may or may not be family members.

# %%
ticket_counts = df['Ticket'].value_counts()
ticket_counts[:15]
# Out:
# CA. 2343        11
# 1601             8
# CA 2144          8
# 347082           7
# S.O.C. 14879     7
# 347077           7
# PC 17608         7
# 3101295          7
# 19950            6
# 113781           6
# 382652           6
# 347088           6
# PC 17757         5
# 349909           5
# 16966            5
# Name: Ticket, dtype: int64

# %% [markdown]
# Create a new column named *TicketCount* that counts the total number of passengers traveling in each passengers' ticket.
#
# Hint:
# - First group passengers based on their tickets using `groupby()` on the *Ticket* column.
# - For the grouped object, pick a column that is a unique identifier for each passenger such as *Name*.
# - Use `transform()` for this unique identifier column with the function `"count"` to create a new column *TicketCount*.
#
# For example, we created *MedianAge* using the following code:
# ```df['MedianAge'] = df.groupby('Title')['Age'].transform("median")```

# %%
df['TicketCount'] = df.groupby('Ticket')['Name'].transform('count')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Family  TicketCount
# 0      0         A/5 21171   7.2500   NaN        S       2            1
# 1      0          PC 17599  71.2833   C85        C       2            2
# 2      0  STON/O2. 3101282   7.9250   NaN        S       1            1
# 3      0            113803  53.1000  C123        S       2            2
# 4      0            373450   8.0500   NaN        S       1            1

# %% [markdown]
# Plot the survival rates based on the *TicketCount* using `sns.barplot()` (see above).

# %%
sns.barplot(x='TicketCount', y='Survived', data=df);

# %% [markdown]
# It does seem that the number of co-travelers have an impact on the survival rate.

# %% [markdown]
# Create a new column named *GroupSize* by picking the maximum value among the columns *Family* and *TicketCount*.
# Note: We consider groups to be either family members or those traveling on the same ticket.
# Hint: Use built-in `max()` function for pandas on the two relevant columns with the appropriate value for the `axis` parameter.

# %%
df['GroupSize'] = df[['Family', 'TicketCount']].max(1)

# %% [markdown]
# Plot the survival rates based on the *GroupSize* using `sns.barplot()`.

# %%
sns.barplot(x='GroupSize', y='Survived', data=df);

# %% [markdown]
# ### Creating a new column using grouping on two columns:
# #### [Predict Future Sales](https://www.kaggle.com/c/competitive-data-science-predict-future-sales) dataset

# %%
path = 'competitive-data-science-predict-future-sales/'
df = pd.read_csv('sales_train.csv')
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# [Read here](https://www.kaggle.com/c/competitive-data-science-predict-future-sales/data) the description for each of the following columns:
# - date
# - date_block_num
# - shop_id
# - item_id
# - item_price
# - item_cnt_day
#
# The aim of the competition is to predict the monthly sales. We are given the daily sales of items in each shop in the column *item_cnt_day*. We want to create a new column named *item_cnt_monthly* that gives the monthly sales of the items using the columns *item_cnt_day* and *date_block_num*.

# %% [markdown]
# Currently, the rows are sorted based on the *date* column. We want them sorted first w.r.t. *date_block_num* and then  w.r.t. *item_id* within each *date_block_num*. Hint: Use `sort_values()` on the two columns: 'date_block_num','item_id'

# %%
df.sort_values(by=['date_block_num', 'item_id'])
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 3280     12.01.2013               0       25       19       28.00
# 9999     02.01.2013               0       19       27     2499.00
# 25924    09.01.2013               0       26       27     2499.00
# 42605    11.01.2013               0        2       27     2499.00
# 44819    12.01.2013               0        1       27     1890.00
# 54389    19.01.2013               0       10       27     1890.00
# 65423    18.01.2013               0       31       27     2499.00
# 113646   04.01.2013               0       45       27     2499.00
# 57746    14.01.2013               0       15       28      549.00
# 65420    16.01.2013               0       31       28      549.00
# 65421    12.01.2013               0       31       28      549.00
# 65422    02.01.2013               0       31       28      549.00
# 69716    03.01.2013               0       35       28      549.00
# 93763    19.01.2013               0       47       28      549.00
# 93764    12.01.2013               0       47       28      549.00
# 115642   06.01.2013               0       46       28      549.00
# 17054    04.01.2013               0       28       29     2499.00
# 44820    26.01.2013               0        1       29     1890.00
# 65418    26.01.2013               0       31       29     2499.00
# 65419    06.01.2013               0       31       29     2499.00
# 90914    18.01.2013               0       50       29     2499.00
# 90915    12.01.2013               0       50       29     2499.00
# 2568     27.01.2013               0       24       32      349.00
# 2580     13.01.2013               0       24       32      349.00
# 3230     10.01.2013               0       25       32      349.00
# 3231     11.01.2013               0       25       32      349.00
# 3232     12.01.2013               0       25       32      349.00
# 3233     14.01.2013               0       25       32      349.00
# 3234     15.01.2013               0       25       32      349.00
# 3235     16.01.2013               0       25       32      349.00
# ...             ...             ...      ...      ...         ...
# 2903580  04.10.2015              33       42    22167      299.00
# 2903581  26.10.2015              33       42    22167      299.00
# 2903582  31.10.2015              33       42    22167      299.00
# 2907457  15.10.2015              33       50    22167      299.00
# 2909683  01.10.2015              33       12    22167      299.00
# 2909684  07.10.2015              33       12    22167      299.00
# 2909685  13.10.2015              33       12    22167      299.00
# 2909686  20.10.2015              33       12    22167      299.00
# 2909687  23.10.2015              33       12    22167      299.00
# 2909688  26.10.2015              33       12    22167      299.00
# 2909689  29.10.2015              33       12    22167      299.00
# 2914184  25.10.2015              33       18    22167      299.00
# 2919236  17.10.2015              33       10    22167      155.00
# 2920248  28.10.2015              33        6    22167      299.00
# 2922486  22.10.2015              33       26    22167      299.00
# 2924951  08.10.2015              33       25    22167      299.00
# 2924952  14.10.2015              33       25    22167      299.00
# 2928370  21.10.2015              33       28    22167      299.00
# 2928969  10.10.2015              33       21    22167      299.00
# 2930877  05.10.2015              33       22    22167      299.00
# 2930878  07.10.2015              33       22    22167      299.00
# 2930879  08.10.2015              33       22    22167      299.00
# 2930880  09.10.2015              33       22    22167      299.00
# 2930881  13.10.2015              33       22    22167      299.00
# 2930882  15.10.2015              33       22    22167      299.00
# 2930883  16.10.2015              33       22    22167      299.00
# 2930884  17.10.2015              33       22    22167      254.15
# 2930885  20.10.2015              33       22    22167      299.00
# 2930886  23.10.2015              33       22    22167      299.00
# 2930887  31.10.2015              33       22    22167      299.00
#
#          item_cnt_day
# 3280              1.0
# 9999              1.0
# 25924             1.0
# 42605             1.0
# 44819             1.0
# 54389             1.0
# 65423             1.0
# 113646            1.0
# 57746             1.0
# 65420             1.0
# 65421             1.0
# 65422             1.0
# 69716             1.0
# 93763             1.0
# 93764             1.0
# 115642            1.0
# 17054             1.0
# 44820             1.0
# 65418             1.0
# 65419             1.0
# 90914            -1.0
# 90915             1.0
# 2568              1.0
# 2580              1.0
# 3230              1.0
# 3231              2.0
# 3232              3.0
# 3233              1.0
# 3234              2.0
# 3235              1.0
# ...               ...
# 2903580           2.0
# 2903581           1.0
# 2903582           1.0
# 2907457           1.0
# 2909683           1.0
# 2909684           1.0
# 2909685           1.0
# 2909686           1.0
# 2909687           1.0
# 2909688           1.0
# 2909689           1.0
# 2914184           1.0
# 2919236           1.0
# 2920248           1.0
# 2922486           1.0
# 2924951           1.0
# 2924952           2.0
# 2928370           1.0
# 2928969           1.0
# 2930877           1.0
# 2930878           2.0
# 2930879           1.0
# 2930880           1.0
# 2930881           2.0
# 2930882           1.0
# 2930883           2.0
# 2930884           1.0
# 2930885           1.0
# 2930886           1.0
# 2930887           1.0
#
# [2935849 rows x 6 columns]

# %% [markdown]
# We sorted the rows so that it will make it easier to check whether our code below is working correctly. For the *date_block_num* equal to 0, we can see that the item with *item_id* 19 is sold once, one with *item_id* 27 is sold 7 times and so on.

# %%
df.head(20)
# Out:
#           date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0   02.01.2013               0       59    22154      999.00           1.0
# 1   03.01.2013               0       25     2552      899.00           1.0
# 2   05.01.2013               0       25     2552      899.00          -1.0
# 3   06.01.2013               0       25     2554     1709.05           1.0
# 4   15.01.2013               0       25     2555     1099.00           1.0
# 5   10.01.2013               0       25     2564      349.00           1.0
# 6   02.01.2013               0       25     2565      549.00           1.0
# 7   04.01.2013               0       25     2572      239.00           1.0
# 8   11.01.2013               0       25     2572      299.00           1.0
# 9   03.01.2013               0       25     2573      299.00           3.0
# 10  03.01.2013               0       25     2574      399.00           2.0
# 11  05.01.2013               0       25     2574      399.00           1.0
# 12  07.01.2013               0       25     2574      399.00           1.0
# 13  08.01.2013               0       25     2574      399.00           2.0
# 14  10.01.2013               0       25     2574      399.00           1.0
# 15  11.01.2013               0       25     2574      399.00           2.0
# 16  13.01.2013               0       25     2574      399.00           1.0
# 17  16.01.2013               0       25     2574      399.00           1.0
# 18  26.01.2013               0       25     2574      399.00           1.0
# 19  27.01.2013               0       25     2574      399.00           1.0

# %% [markdown]
# We can use `groupby()` on the two columns - *date_block_num* and *item_id* and sum the values in the *item_cnt_day* column in each grouping as follows.

# %%
df.groupby(['date_block_num', 'item_id'])['item_cnt_day'].sum()
# Out:
# date_block_num  item_id
# 0               19           1.0
#                 27           7.0
#                 28           8.0
#                 29           4.0
#                 32         299.0
#                 33          61.0
#                 34           9.0
#                 35          78.0
#                 40           4.0
#                 41           9.0
#                 42           2.0
#                 43           2.0
#                 44           6.0
#                 45           8.0
#                 46           2.0
#                 47           6.0
#                 48           7.0
#                 49           5.0
#                 50           2.0
#                 51          13.0
#                 52           7.0
#                 53           8.0
#                 54           6.0
#                 55           4.0
#                 56           1.0
#                 57           1.0
#                 59          18.0
#                 60           6.0
#                 61           2.0
#                 63           4.0
#                            ...
# 33              22020        1.0
#                 22050        3.0
#                 22051        6.0
#                 22058        3.0
#                 22059        2.0
#                 22060        5.0
#                 22071        5.0
#                 22072        1.0
#                 22076        4.0
#                 22087       87.0
#                 22088      185.0
#                 22091       30.0
#                 22092       46.0
#                 22100      158.0
#                 22101       54.0
#                 22102      227.0
#                 22104       14.0
#                 22105       11.0
#                 22106        6.0
#                 22111        1.0
#                 22118        2.0
#                 22139        9.0
#                 22145       13.0
#                 22154        5.0
#                 22158        1.0
#                 22162       10.0
#                 22163       26.0
#                 22164       15.0
#                 22166       11.0
#                 22167       37.0
# Name: item_cnt_day, Length: 233912, dtype: float64

# %% [markdown]
# Create a new column named *item_cnt_monthly* that gives the monthly sales of the items
#
# Hint:
# - First group the rows using `groupby()` on the two columns - *date_block_num* and *item_id*.
# - For the grouped object, select the *item_cnt_day* column.
# - Use `transform()` for this column with the function `"sum"` to create a new column named *item_cnt_monthly*.

# %%
df['item_cnt_monthly'] = df.groupby(['date_block_num', 'item_id'])['item_cnt_day'].transform('sum')

# %% [markdown]
# Check that the code indeed worked as expected.

# %%
df.head(25)
# Out:
#           date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0   02.01.2013               0       59    22154      999.00           1.0
# 1   03.01.2013               0       25     2552      899.00           1.0
# 2   05.01.2013               0       25     2552      899.00          -1.0
# 3   06.01.2013               0       25     2554     1709.05           1.0
# 4   15.01.2013               0       25     2555     1099.00           1.0
# 5   10.01.2013               0       25     2564      349.00           1.0
# 6   02.01.2013               0       25     2565      549.00           1.0
# 7   04.01.2013               0       25     2572      239.00           1.0
# 8   11.01.2013               0       25     2572      299.00           1.0
# 9   03.01.2013               0       25     2573      299.00           3.0
# 10  03.01.2013               0       25     2574      399.00           2.0
# 11  05.01.2013               0       25     2574      399.00           1.0
# 12  07.01.2013               0       25     2574      399.00           1.0
# 13  08.01.2013               0       25     2574      399.00           2.0
# 14  10.01.2013               0       25     2574      399.00           1.0
# 15  11.01.2013               0       25     2574      399.00           2.0
# 16  13.01.2013               0       25     2574      399.00           1.0
# 17  16.01.2013               0       25     2574      399.00           1.0
# 18  26.01.2013               0       25     2574      399.00           1.0
# 19  27.01.2013               0       25     2574      399.00           1.0
# 20  09.01.2013               0       25     2593      279.00           1.0
# 21  16.01.2013               0       25     2604      299.00           1.0
# 22  27.01.2013               0       25     2604      299.00           1.0
# 23  27.01.2013               0       25     2607      279.00           1.0
# 24  29.01.2013               0       25     2607      279.00           1.0
#
#     item_cnt_monthly
# 0               18.0
# 1                0.0
# 2                0.0
# 3                1.0
# 4                2.0
# 5                5.0
# 6                2.0
# 7               12.0
# 8               12.0
# 9               16.0
# 10             119.0
# 11             119.0
# 12             119.0
# 13             119.0
# 14             119.0
# 15             119.0
# 16             119.0
# 17             119.0
# 18             119.0
# 19             119.0
# 20               5.0
# 21              10.0
# 22              10.0
# 23              29.0
# 24              29.0

# %% [markdown]
# ### Merging columns from different datasets:

# %% [markdown]
# A simple illustration to merge two datasets using `merge()`

# %%
df1 = pd.DataFrame({'CourseCode': ['PHYS024', 'CSCI35', 'ENGR156'], 
                   'CourseName': ['Mechanics and Wave Motion', 
                                  'Computer Science for Insight',
                                 'Intro to Comm & Info Theory']})

df2 = pd.DataFrame({'Professor': ['Zachary Dodds', 'Vatche Sahakian', 
                                  'Timothy Tsai', 'Brian Shuve'],
                    'CourseCode': ['CSCI35', 'PHYS024',  'ENGR156', 'PHYS024']})

df1.head()
# Out:
#   CourseCode                    CourseName
# 0    PHYS024     Mechanics and Wave Motion
# 1     CSCI35  Computer Science for Insight
# 2    ENGR156   Intro to Comm & Info Theory

# %%
df2.head()
# Out:
#          Professor CourseCode
# 0    Zachary Dodds     CSCI35
# 1  Vatche Sahakian    PHYS024
# 2     Timothy Tsai    ENGR156
# 3      Brian Shuve    PHYS024

# %%
pd.merge(df2, df1)
# Out:
#          Professor CourseCode                    CourseName
# 0    Zachary Dodds     CSCI35  Computer Science for Insight
# 1  Vatche Sahakian    PHYS024     Mechanics and Wave Motion
# 2      Brian Shuve    PHYS024     Mechanics and Wave Motion
# 3     Timothy Tsai    ENGR156   Intro to Comm & Info Theory

# %% [markdown]
# #### [Instacart Market Basket Analysis](https://www.kaggle.com/c/instacart-market-basket-analysis/data)
# Load the four files into separate dataframes: `aisles.csv`, `departments.csv`, `products.csv`, and `order_products__train.csv`:

# %%
df1 = pd.read_csv('aisles.csv')
df2 = pd.read_csv('departments.csv')
df3 = pd.read_csv('products.csv')
df4 = pd.read_csv('order_products__train.csv')

# %% [markdown]
# Familiarize yourself with the dataframes. Hint: Use `head()`.

# %%
df4.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %% [markdown]
# Get a dataframe consisting of the name of the products along with their aisle names and department names for the order with `order_id` equal to 1. Note: dataframe must have 8 rows and only three columns:
# ```'product_name', 'aisle', 'department'```
#
# Hint:
# - First slice out 8 rows from the order_products dataframe that corresponds with `order_id` equal to 1 and save it in a dataframe.
# - Use `merge()` multiple times to merge two dataframes at a time.
# - Finally slice out the 3 selective columns: `'product_name', 'aisle', 'department'`

# %%
dfm = df4[df4['order_id'] == 1]
dfm = pd.merge(dfm, df3)
dfm = pd.merge(dfm, df2)
dfm = pd.merge(dfm, df1)
dfm[['product_name', 'aisle', 'department']]
# Out:
#                                     product_name                 aisle  \
# 0                               Bulgarian Yogurt                yogurt
# 1  Organic 4% Milk Fat Whole Milk Cottage Cheese  other creams cheeses
# 2                    Organic Whole String Cheese       packaged cheese
# 3                          Organic Celery Hearts      fresh vegetables
# 4                                 Cucumber Kirby      fresh vegetables
# 5                         Bag of Organic Bananas          fresh fruits
# 6                           Organic Hass Avocado          fresh fruits
# 7           Lightly Smoked Sardines in Olive Oil   canned meat seafood
#
#      department
# 0    dairy eggs
# 1    dairy eggs
# 2    dairy eggs
# 3       produce
# 4       produce
# 5       produce
# 6       produce
# 7  canned goods

# %% [markdown]
# It isn't completely clear what some of the column names mean such as (SibSp and Parch)
#
# Little to no critical thinking is required to "Create a new column named item_cnt_monthly that gives the monthly sales of the items" due to the hint given
#
# Maybe ask what merge does, as its not completely obvious and the student could complete the rest of the exercises without a good understanding of what it actually does
#
# I think 45 minutes may be a bit too much time.
#
# Maybe state the objective ofthe first excercise at the top
